# %% [markdown]
# # Crawl data

# %% [markdown]
# NOTE: Cần đăng nhập tài khoản trả phí của Luatvietnam.vn, sau đấy lấy gói tin get -> copy bash curl -> convert sang python request để lấy cookies, header, param cho search -> lấy cookies, headers cho download

# %% [markdown]
# Lấy link download với 6347 Luật, Nghị Định, Thông tư ~ 4GB

# %%
import requests
from bs4 import BeautifulSoup
import os
cookies = {
    '_fbp': 'fb.1.1740842273081.50061238653342381',
    '_gta_uni': '823749984.308972800.094934686275',
    '__vnp_guest_id': '308972800',
    '_hjSessionUser_5192214': 'eyJpZCI6IjdjZjdiMDhjLTE4YmYtNTY2OC1iZWI3LTQ3NDllMWY0YmIyMyIsImNyZWF0ZWQiOjE3NDA4NDIyNzQzMzMsImV4aXN0aW5nIjp0cnVlfQ==',
    '__RC': '4',
    '__R': '1',
    '_uidcms': '3474027811156811806',
    '__tb': '0',
    '__IP': '712174308',
    '__gads': 'ID=8d7147c3cd803e1c:T=1744012390:RT=1744013920:S=ALNI_Maz1F9B0xL9vRoMo0Nd5CQ9u1OHzA',
    '__gpi': 'UID=0000108ebbf86ec0:T=1744012390:RT=1744013920:S=ALNI_MbEo6_OBwjHgZoJo4FqrgD39vrq0A',
    '__eoi': 'ID=c9b9c7a4c6926e6c:T=1741081644:RT=1744013920:S=AA-AfjaRjm3V17u2O0FHBVbhcCc7',
    '_ga_EW2DZ6FMZM': 'GS1.2.1744014160.8.1.1744014238.0.0.0',
    '_ga_ZWHEHZ2EHL': 'GS1.1.1744014159.8.1.1744014299.60.0.1583616139',
    'LAWSVN_AUTH': '...',
    'ASP.NET_SessionId': 'qfqulfqnhl5gm3rfpm3effsn',
    '_gid': 'GA1.2.330078096.1744710080',
    '_hjSession_5192214': 'eyJpZCI6IjM0ZWYzMzk0LTBlYjYtNGRjMS1hMzE1LTUyZTQ1NTU1Y2M3YiIsImMiOjE3NDQ3MTAwODA0NjcsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=',
    '_clck': 'ctmcgk%7C2%7Cfv3%7C0%7C1886',
    '_ga_2GQESC9SL5': 'GS1.1.1744710080.15.1.1744710125.0.0.996032331',
    '_ga': 'GA1.2.45364532.1740842274',
    '_clsk': 'jkkf1s%7C1744710126626%7C3%7C1%7Ci.clarity.ms%2Fcollect',
}

headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'en,vi;q=0.9,en-US;q=0.8',
    'cache-control': 'max-age=0',
    'priority': 'u=0, i',
    'referer': 'https://luatvietnam.vn/van-ban/tim-van-ban.html',
    'sec-ch-ua': '"Microsoft Edge";v="135", "Not-A.Brand";v="8", "Chromium";v="135"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/135.0.0.0 Safari/537.36 Edg/135.0.0.0',
    # 'cookie': '_fbp=fb.1.1740842273081.50061238653342381; _gta_uni=823749984.308972800.094934686275; __vnp_guest_id=308972800; _hjSessionUser_5192214=eyJpZCI6IjdjZjdiMDhjLTE4YmYtNTY2OC1iZWI3LTQ3NDllMWY0YmIyMyIsImNyZWF0ZWQiOjE3NDA4NDIyNzQzMzMsImV4aXN0aW5nIjp0cnVlfQ==; __RC=4; __R=1; _uidcms=3474027811156811806; __tb=0; __IP=712174308; __gads=ID=8d7147c3cd803e1c:T=1744012390:RT=1744013920:S=ALNI_Maz1F9B0xL9vRoMo0Nd5CQ9u1OHzA; __gpi=UID=0000108ebbf86ec0:T=1744012390:RT=1744013920:S=ALNI_MbEo6_OBwjHgZoJo4FqrgD39vrq0A; __eoi=ID=c9b9c7a4c6926e6c:T=1741081644:RT=1744013920:S=AA-AfjaRjm3V17u2O0FHBVbhcCc7; _ga_EW2DZ6FMZM=GS1.2.1744014160.8.1.1744014238.0.0.0; _ga_ZWHEHZ2EHL=GS1.1.1744014159.8.1.1744014299.60.0.1583616139; LAWSVN_AUTH=...; ASP.NET_SessionId=qfqulfqnhl5gm3rfpm3effsn; _gid=GA1.2.330078096.1744710080; _hjSession_5192214=eyJpZCI6IjM0ZWYzMzk0LTBlYjYtNGRjMS1hMzE1LTUyZTQ1NTU1Y2M3YiIsImMiOjE3NDQ3MTAwODA0NjcsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=; _clck=ctmcgk%7C2%7Cfv3%7C0%7C1886; _ga_2GQESC9SL5=GS1.1.1744710080.15.1.1744710125.0.0.996032331; _ga=GA1.2.45364532.1740842274; _clsk=jkkf1s%7C1744710126626%7C3%7C1%7Ci.clarity.ms%2Fcollect',
}

def get_download_links(page_index):
    params = [
    ('keywords', ''),
    ('SearchOptions', '1'),
    ('SearchByDate', 'issueDate'),
    ('DateFromString', ''),
    ('DateToString', ''),
    ('search', ''),
    ('DocTypeIds', ''),
    ('search', ''),
    ('OrganIds', '0'),
    ('search', ''),
    ('FieldIds', '64'),
    ('LanguageId', '0'),
    ('SignerIds', '0'),
    ('SignerIds', '0'),
    ('RowAmount', '20'),
    ('PageIndex', page_index)
]
       
    response = requests.get('https://luatvietnam.vn/van-ban/tim-van-ban.html', params=params, cookies=cookies, headers=headers)
    soup = BeautifulSoup(response.text, 'html.parser')
    BASE_URL = "luatvietnam.vn"
    block_content = soup.find("div", class_="block-content-resut")

    if block_content:
        # Tìm tất cả các <article> trong block-content-resut
        articles = block_content.find_all("article", class_="art-search")
        links = ""
        # Duyệt qua từng article để lấy link và tiêu đề
        for article in articles:
            title_tag = article.find("h2", class_="doc-title").find("a")  # Lấy thẻ <a> trong tiêu đề
            if title_tag:
                href = BASE_URL + title_tag["href"] + "#taive" # Tạo link đầy đủ
                title = title_tag["title"]  # Lấy tiêu đề
                links +=href + "\n"
    return links

def write_all_links_to_file(nbr_docs, file_path):
    nbr_index = nbr_docs//20 
    f = open(file_path, 'w')
    for idx in range(nbr_index):
        links = get_download_links(idx+1)
        f.write(links)
    f.close()

# %%
write_all_links_to_file(240,'total_law_download_links.txt')

# %%
# lấy lại cookies, header
download_cookies = {
    '_fbp': 'fb.1.1740842273081.50061238653342381',
    '_gta_uni': '823749984.308972800.094934686275',
    '__vnp_guest_id': '308972800',
    '_hjSessionUser_5192214': 'eyJpZCI6IjdjZjdiMDhjLTE4YmYtNTY2OC1iZWI3LTQ3NDllMWY0YmIyMyIsImNyZWF0ZWQiOjE3NDA4NDIyNzQzMzMsImV4aXN0aW5nIjp0cnVlfQ==',
    '__RC': '4',
    '__R': '1',
    '_uidcms': '3474027811156811806',
    '__tb': '0',
    '__eoi': 'ID=c9b9c7a4c6926e6c:T=1741081644:RT=1741081644:S=AA-AfjaRjm3V17u2O0FHBVbhcCc7',
    '__IP': '712174308',
    '__uif': '__uid%3A3474027811156811806%7C__ui%3A-1%7C__create%3A1743142145',
    'LAWSVN_AUTH': '...',
    '_gid': 'GA1.2.1074167814.1743653376',
    '_hjSession_5192214': 'eyJpZCI6IjM2OWIyNzcwLTFjYjktNDAxMi05NWI4LWQzNGZiMWQzNmMxOSIsImMiOjE3NDM2NTMzNzU2NjMsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MX0=',
    '_clck': 'ctmcgk%7C2%7Cfur%7C0%7C1886',
    'ASP.NET_SessionId': 'favrx2ms12pigpdxbsjfg0i2',
    '_ga_2GQESC9SL5': 'GS1.1.1743653375.9.1.1743653384.0.1.213089278',
    '_ga_ZWHEHZ2EHL': 'GS1.1.1743653384.6.0.1743653384.60.0.454077900',
    '_ga_EW2DZ6FMZM': 'GS1.2.1743653384.6.0.1743653384.0.0.0',
    '_ga': 'GA1.2.45364532.1740842274',
    '_clsk': 'dcbiig%7C1743654368920%7C3%7C1%7Cu.clarity.ms%2Fcollect',
}

download_headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'accept-language': 'en,vi;q=0.9,en-US;q=0.8',
    'cache-control': 'max-age=0',
    'priority': 'u=0, i',
    'referer': 'https://luatvietnam.vn/van-ban/tim-van-ban.html?keywords=&SearchOptions=1&SearchByDate=issueDate&DateFromString=&DateToString=&search=&DocTypeIds=10&DocTypeIds=11&DocTypeIds=13&DocTypeIds=17&DocTypeIds=21&search=&OrganIds=0&EffectStatusIds=4&search=&FieldIds=64&LanguageId=1&SignerIds=0&SignerIds=0',
    'sec-ch-ua': '"Chromium";v="134", "Not:A-Brand";v="24", "Microsoft Edge";v="134"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/134.0.0.0 Safari/537.36 Edg/134.0.0.0',
    # 'cookie': '_fbp=fb.1.1740842273081.50061238653342381; _gta_uni=823749984.308972800.094934686275; __vnp_guest_id=308972800; _hjSessionUser_5192214=eyJpZCI6IjdjZjdiMDhjLTE4YmYtNTY2OC1iZWI3LTQ3NDllMWY0YmIyMyIsImNyZWF0ZWQiOjE3NDA4NDIyNzQzMzMsImV4aXN0aW5nIjp0cnVlfQ==; __RC=4; __R=1; _uidcms=3474027811156811806; __tb=0; __eoi=ID=c9b9c7a4c6926e6c:T=1741081644:RT=1741081644:S=AA-AfjaRjm3V17u2O0FHBVbhcCc7; __IP=712174308; __uif=__uid%3A3474027811156811806%7C__ui%3A-1%7C__create%3A1743142145; LAWSVN_AUTH=...; _gid=GA1.2.1074167814.1743653376; _hjSession_5192214=eyJpZCI6IjM2OWIyNzcwLTFjYjktNDAxMi05NWI4LWQzNGZiMWQzNmMxOSIsImMiOjE3NDM2NTMzNzU2NjMsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MX0=; _clck=ctmcgk%7C2%7Cfur%7C0%7C1886; ASP.NET_SessionId=favrx2ms12pigpdxbsjfg0i2; _ga_2GQESC9SL5=GS1.1.1743653375.9.1.1743653384.0.1.213089278; _ga_ZWHEHZ2EHL=GS1.1.1743653384.6.0.1743653384.60.0.454077900; _ga_EW2DZ6FMZM=GS1.2.1743653384.6.0.1743653384.0.0.0; _ga=GA1.2.45364532.1740842274; _clsk=dcbiig%7C1743654368920%7C3%7C1%7Cu.clarity.ms%2Fcollect',
}
def download_pdfs_from_page(url, download_folder="downloads"):
    response = requests.get(url, cookies=download_cookies, headers=download_headers)
    response.raise_for_status()
    
    soup = BeautifulSoup(response.text, 'html.parser')
    vn_doc_section = soup.find('div', class_='vn-doc')
    
    if not vn_doc_section:
        print("Không tìm thấy phần tử có class 'vn-doc'.")
        return
    
    links = vn_doc_section.find_all('a', href=lambda href: href and href.endswith('.docx'))
    
    if not links:
        links = vn_doc_section.find_all('a', href=lambda href: href and href.endswith('.doc'))
        
    if not links:
        links = vn_doc_section.find_all('a', href=lambda href: href and href.endswith('.pdf'))
    
    if not links:
       print('NO DOCUMENT') 
    os.makedirs(download_folder, exist_ok=True)
    
    for link in links:
        file_url = link['href']
        filename = os.path.basename(file_url)
        filepath = os.path.join(download_folder, filename)
        
        file_response = requests.get(file_url,cookies=download_cookies, headers=download_headers, stream=True)
        file_response.raise_for_status()
        
        with open(filepath, 'wb') as f:
            for chunk in file_response.iter_content(chunk_size=8192):
                f.write(chunk)
        
        print(f"File downloaded: {filepath}")
with open('total_law_download_links.txt','r') as f:
    for line in f:
        link = 'https://'  + line.strip()
        download_pdfs_from_page(url = link, download_folder='./data/corpus')
# Out:
# File downloaded: data/corpus\1513_bvhttdl_vhcsgdtv_110425101010.pdf
# File downloaded: data/corpus\957_kh_ubnd_040425163837.pdf
# File downloaded: data/corpus\72_kh_ubnd_150325085917.pdf
# File downloaded: data/corpus\114_kh_ubnd_250225111944.pdf
# File downloaded: data/corpus\06_2025_nd_cp_100125095431.docx
# File downloaded: data/corpus\3963_qd_bvhttdl_231224105557.docx
# File downloaded: data/corpus\6545_vbhn_btp_2024_281124134735.pdf
# File downloaded: data/corpus\61_2024_qd_ubnd_caobang_111224142148.pdf
# File downloaded: data/corpus\3046_qd_bvhttdl_131224213406.docx
# File downloaded: data/corpus\3048_qd_bvhttdl_140425082907.docx
# File downloaded: data/corpus\3854_vkstc_v9_080425160321.docx
# File downloaded: data/corpus\27_ct_ttg_160824155840.docx
# File downloaded: data/corpus\157_kh_ubnd_210824145002.pdf
# File downloaded: data/corpus\58_2024_tt_btc_090824095927.docx
# File downloaded: data/corpus\1667_qd_bvhttdl_250624141835.docx
# ...
